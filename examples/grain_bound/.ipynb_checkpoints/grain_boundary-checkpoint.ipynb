# %%
import numpy as np
import combo
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
A = np.asarray(np.loadtxt('s5-210.csv',skiprows=1,delimiter=','))
X = A[:,0:3]
t = A[:,3]

# %%
index = np.random.permutation(xrange(X.shape[0]))
X = X[index,:]
t = t[index]

# %%
mean = combo.gp.mean.const()
cov = combo.gp.cov.gauss( X.shape[1] )
lik = combo.gp.lik.gauss()
gp = combo.gp.model( mean = mean, cov = cov, lik = lik )

# %%
config = combo.misc.set_config()
config.load('config.ini')

# %%
class simulator:
    def __init__(self):
        A = np.asarray(np.loadtxt('s5-210.csv',skiprows=1,delimiter=','))
        X = A[:,0:3]
        t = A[:,3]
    def __call__(self, action):
        return -t[action]

# %%
simu = simulator()
search=combo.search.bayes_policy(simu)
# Out:
# -1.036773793

# %%
gp.comp_stats(Xtrain, ttrain)
fhat = gp.get_post_fmean(Xtrain, Xtest)
plt.plot(ttest, fhat,'o')
np.corrcoef(ttest,fhat)
# Out:
# array([[ 1.        ,  0.35098322],
#        [ 0.35098322,  1.        ]])

# %%
gp.learn(Xtrain,ttrain)
# Out:
# likelihood parameter:  [-2.46988701]
# mean parameter of prior:  [ 1.07204909]
# covariance parameter of prior:  [ 1.25402669 -1.90194016  0.85120292 -2.6378354 ]

# %%
plt.imshow(gp.prior.get_cov(Xtrain))

# %%
gp.comp_stats(Xtrain, ttrain)
fhat = gp.get_post_fmean(Xtrain, Xtest)

# %%
plt.plot(ttest, fhat,'o')
np.corrcoef(ttest,fhat)
# Out:
# array([[ 1.        ,  0.33007724],
#        [ 0.33007724,  1.        ]])

# %%
plt.plot(gp.get_post_fcov(Xtrain,Xtest))
